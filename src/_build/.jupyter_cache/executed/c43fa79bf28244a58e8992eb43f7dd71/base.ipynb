% %%
a = 0.5;
for C = [-1 -0.5 -0.25 0 0.25 0.5 1]
    fplot(@(t) C*exp(a*t),[0,6])
    hold on
end

plot(2,5,'ko')
fplot(@(t) 5*exp(a*(t-2)),[0,6])
% Out:
% Unrecognized function or variable 'gobjects'.
%
% Error in newplot (line 47)
% fig = gobjects(0);
%
% Error in fplot (line 159)
%         cax = newplot(cax);

% %%
restoredefaultpath

% %%
%plot -s 750,400 -r 100

% %%
f = @(t,x) 0.1*x;
t = linspace(1,5,300);
[t,x] = ode45(f,t,3);
clf
plot(t,x)
xlabel('t'), ylabel('x')

% %%
semilogy(t,x)
xlabel('t'), ylabel('x')

% %%
f = @(t,x) 2*t*x;
t = linspace(0,5,300);
[t,x] = ode45(f,t,1);
clf
semilogy(t,x)
xlabel('t'), ylabel('x')

% %%
f = @(t,x) x^2;
t = linspace(0,4,300);
[t,x] = ode45(f,t,0.5);
semilogy(t,x)
xlabel('t'), ylabel('x')
% Out:
% ...
% > In ode45 (line 360)
